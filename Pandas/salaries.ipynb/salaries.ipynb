# %%
# importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing the salaries data into python environment
salaries=pd.read_csv(r"C:\Users\priya v\Downloads\Salaries.csv")
# Out:
# C:\Users\priya v\AppData\Local\Temp\ipykernel_7116\577811998.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   salaries=pd.read_csv(r"C:\Users\priya v\Downloads\Salaries.csv")

# %%
# Display the top 10 rows of the dataset.
salaries.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
# Check the last 10 rows of the dataset
salaries.tail(10)
# Out:
#             Id      EmployeeName                      JobTitle       BasePay  \
# 148644  148645      Randy D Winn  Stationary Eng, Sewage Plant          0.00
# 148645  148646  Carolyn A Wilson     Human Services Technician          0.00
# 148646  148647      Not provided                  Not provided  Not Provided
# 148647  148648    Joann Anderson   Communications Dispatcher 2          0.00
# 148648  148649       Leon Walker                     Custodian          0.00
# 148649  148650     Roy I Tillery                     Custodian          0.00
# 148650  148651      Not provided                  Not provided  Not Provided
# 148651  148652      Not provided                  Not provided  Not Provided
# 148652  148653      Not provided                  Not provided  Not Provided
# 148653  148654         Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits  TotalPay  TotalPayBenefits  \
# ...

# %%
#Find the shape of the dataset
salaries.shape
# Out:
# (148654, 13)

# %%
#Get information about the dataset, including total rows, columns, data types, and memory usage.
salaries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
#Check for null values in the dataset
salaries.isna().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64

# %%
#Drop columns such as ID, Notes, Agency, and Status.
salaries1=salaries.drop(columns=["Id","Notes","Agency","Status"])

# %%
#Replace 'Not Provided' in the EmployeeName column with NaN.
salaries1["EmployeeName"]
salaries1.replace({"Not provided":"NaN"})
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650                NaN                                             NaN
# 148651                NaN                                             NaN
# 148652                NaN                                             NaN
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %%
salaries1["EmployeeName"].str.replace("Not provided", "NaN")
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650                  NaN
# 148651                  NaN
# 148652                  NaN
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
#Drop rows with more than 5 missing values
salaries1.dropna()
# Out:
#               EmployeeName                      JobTitle       BasePay  \
# 36159       Gary Altenberg  Lieutenant, Fire Suppression     128808.87
# 36160         Gregory Suhr               Chief of Police      302578.0
# 36161           Khoa Trinh   Electronic Maintenance Tech      111921.0
# 36162   Joanne Hayes-White        Chief, Fire Department     296943.01
# 36163    Frederick Binkley     EMT/Paramedic/Firefighter     126863.19
# ...                    ...                           ...           ...
# 148649       Roy I Tillery                     Custodian          0.00
# 148650        Not provided                  Not provided  Not Provided
# 148651        Not provided                  Not provided  Not Provided
# 148652        Not provided                  Not provided  Not Provided
# 148653           Joe Lopez    Counselor, Log Cabin Ranch          0.00
#
#          OvertimePay      OtherPay      Benefits   TotalPay  TotalPayBenefits  \
# ...

# %%
#Find the number of unique job titles
salaries1["JobTitle"].nunique()
# Out:
# 2159

# %%
#Find the occurrence of employee names
salaries1["EmployeeName"].value_counts()
# Out:
# Kevin Lee                   13
# Richard Lee                 11
# Steven Lee                  11
# William Wong                11
# Stanley Lee                  9
#                             ..
# Jeffrey Skover               1
# Ken Dever                    1
# Kevin Whitfield              1
# Granville McCollough III     1
# Joe Lopez                    1
# Name: EmployeeName, Length: 110811, dtype: int64

# %%
#the average BasePay of all employees per year
avg_Basepay=salaries1[["BasePay","EmployeeName"]].mean
print(avg_Basepay)
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of              BasePay       EmployeeName
# 0          167411.18     NATHANIEL FORD
# 1          155966.02       GARY JIMENEZ
# 2          212739.13     ALBERT PARDINI
# 3            77916.0  CHRISTOPHER CHONG
# 4           134401.6    PATRICK GARDNER
# ...              ...                ...
# 148649          0.00      Roy I Tillery
# 148650  Not Provided       Not provided
# 148651  Not Provided       Not provided
# 148652  Not Provided       Not provided
# 148653          0.00          Joe Lopez
#
# [148654 rows x 2 columns]>

# %%
#the average BasePay of employees with the job title
avg_Basepay=salaries1[["EmployeeName","BasePay","JobTitle"]].mean
avg_Basepay
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of              EmployeeName       BasePay  \
# 0          NATHANIEL FORD     167411.18
# 1            GARY JIMENEZ     155966.02
# 2          ALBERT PARDINI     212739.13
# 3       CHRISTOPHER CHONG       77916.0
# 4         PATRICK GARDNER      134401.6
# ...                   ...           ...
# 148649      Roy I Tillery          0.00
# 148650       Not provided  Not Provided
# 148651       Not provided  Not Provided
# 148652       Not provided  Not Provided
# 148653          Joe Lopez          0.00
#
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# ...

# %%
#the top 5 highest-paid employees
salaries1.sort_values(by="TotalPay",ascending=False).head(5)
# Out:
#           EmployeeName                                        JobTitle  \
# 0       NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1         GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 110531     David Shinn                                  Deputy Chief 3
# 110532      Amy P Hart                               Asst Med Examiner
# 36159   Gary Altenberg                    Lieutenant, Fire Suppression
#
#           BasePay OvertimePay   OtherPay  Benefits   TotalPay  \
# 0       167411.18         0.0  400184.25       NaN  567595.43
# 1       155966.02   245131.88  137811.38       NaN  538909.28
# 110531  129150.01         0.0  342802.63  38780.04  471952.64
# 110532  318835.49    10712.95   60563.54  89540.23  390111.98
# 36159   128808.87   220909.48   13126.31  44430.12  362844.66
#
#         TotalPayBenefits  Year
# 0              567595.43  2011
# 1              538909.28  2011
# 110531         510732.68  2014
# 110532         479652.21  2014
# ...

# %%
#the median BasePay for each department.
salaries1[["JobTitle","BasePay"]].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of                                               JobTitle       BasePay
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# 148649                                       Custodian          0.00
# 148650                                    Not provided  Not Provided
# 148651                                    Not provided  Not Provided
# 148652                                    Not provided  Not Provided
# 148653                      Counselor, Log Cabin Ranch          0.00
#
# [148654 rows x 2 columns]>

# %%
#the job title of 'ALBERT PARDINI'
salaries1.loc[salaries1["EmployeeName"]=="ALBERT PARDINI","JobTitle"]
# Out:
# 2    CAPTAIN III (POLICE DEPARTMENT)
# Name: JobTitle, dtype: object

# %%
#ALBERT PARDINI' make (including benefits)
salaries1.loc[salaries1["EmployeeName"]=="ALBERT PARDINI","TotalPayBenefits"]
# Out:
# 2    335279.91
# Name: TotalPayBenefits, dtype: float64

# %%
#coverting to numeric
salaries1["BasePay"]=pd.to_numeric(salaries1["BasePay"],errors='coerce')

# %%
#the name of the person with the highest BasePay
salaries1.loc[salaries1["BasePay"].astype(float).idxmax(),"EmployeeName"]
# Out:
# 'Gregory P Suhr'

# %%
#the employee with the lowest BasePay
salaries1.loc[salaries1["BasePay"].astype(float).idxmin(),"EmployeeName"]
# Out:
# 'Irwin Sidharta'

# %%
#employee worked for the most number of years
salaries1["EmployeeName"].value_counts().idxmax()
# Out:
# 'Kevin Lee'

# %%
#the total number of employees in each department
salaries1["JobTitle"].value_counts()
# Out:
# Transit Operator                                  7036
# Special Nurse                                     4389
# Registered Nurse                                  3736
# Public Svc Aide-Public Works                      2518
# Police Officer 3                                  2421
#                                                   ...
# CHIEF HOUSING INSPECTOR                              1
# TRAFFIC SIGNAL OPERATOR                              1
# COURT COMPUTER FACILITIES COORDINATOR                1
# AUTOMOTIVE BODY AND FENDER WORKER SUPERVISOR I       1
# VICTIM & WITNESS TECHNICIAN                          1
# Name: JobTitle, Length: 2159, dtype: int64

# %%
#the top 5 most common job titles
salaries1["JobTitle"].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
#job titles contain the word 'Captain'
salaries1[salaries1["JobTitle"].str.contains("Captain",case=False,na=False)].shape[0]
# Out:
# 552

# %%
#the top 3 most common benefits
salaries1["Benefits"].value_counts().head(3)
# Out:
# 0.0        1053
# 0.00        681
# 7959.18     348
# Name: Benefits, dtype: int64

# %%
#percentage of BasePay is missing in the dataset
(salaries1["BasePay"].isna().sum()/len(salaries1))*100
# Out:
# 0.40967616074912216

# %%
#the top 3 years with the smallest TotalPayBenefits
salaries1.groupby("Year")["TotalPayBenefits"].sum().nsmallest(3)
# Out:
# Year
# 2011    2.594195e+09
# 2012    3.696940e+09
# 2013    3.814772e+09
# Name: TotalPayBenefits, dtype: float64

# %%
#histogram of TotalPay
plt.hist(salaries1["TotalPay"], bins=10, alpha=0.5, edgecolor='black') 
plt.ylabel('TotalPay')
plt.xlabel('Frequency')
plt.title('Histogram')
plt.show()
